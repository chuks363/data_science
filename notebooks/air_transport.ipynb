# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd

# %% [markdown]
# # Data Loading

# %%
# Load the CSV file
df = pd.read_excel("C:\\Users\\frank\\data_science_project_advance\\datasets\\air_transport.xlsx")

# %% [markdown]
# # Exploration

# %% [markdown]
# ## Inspecting the data

# %%
# Check the first few rows
print(df.head())

# Check column data types and missing values
print(df.info())

# Get summary statistics
print(df.describe(include='all'))
# Out:
#   PASSENGERS MOVEMENT DOMESTIC Unnamed: 1   Unnamed: 2   Unnamed: 3  \
# 0                          NaN        NaN      Q1 2021          NaN
# 1                          S/N   AIRPORTS  Q1 2021_ARR  Q1 2021_DEP
# 2                            1      LAGOS       404939       359937
# 3                            2      ABUJA       469599       462810
# 4                            3        PHC        80225        84788
#
#     Unnamed: 4   Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8  \
# 0      Q2 2021          NaN      Q3 2021          NaN      Q4 2021
# 1  Q2 2021_ARR  Q2 2021_DEP  Q3 2021_ARR  Q3 2021_DEP  Q4 2021_ARR
# 2       433881       427439       571425       539878       673323
# 3       506374       510507       672419       658479       714818
# 4        94135        96071       119135       118205       164365
#
#     Unnamed: 9  ...       Unnamed: 79       Unnamed: 80      Unnamed: 81  \
# 0          NaN  ...           Q3 2021               NaN              NaN
# ...

# %% [markdown]
# ## Drop Completely Empty Columns

# %%
df.dropna(axis=1, how='all', inplace=True)
print(df)
# Out:
#    Unnamed: 0 Unnamed: 1      Q1 2021   Unnamed: 3      Q2 2021   Unnamed: 5  \
# 0         S/N   AIRPORTS  Q1 2021_ARR  Q1 2021_DEP  Q2 2021_ARR  Q2 2021_DEP
# 1           1      LAGOS       404939       359937       433881       427439
# 2           2      ABUJA       469599       462810       506374       510507
# 3           3        PHC        80225        84788        94135        96071
# 4           4       KANO        56021        56660        55127        54471
# 5           5      ENUGU        48283        55088        60615        62808
# 6           6      OSUBI            0            0            0            0
# 7           7     KADUNA         9915         8838         5203         5174
# 8           8    CALABAR        17162        17647        20802        21111
# 9           9     SOKOTO        12442        12670        15449        15132
# 10         10      BENIN        39241        40707        43843        44959
# ...

# %% [markdown]
# ## Rename Column Properly

# %%
df.rename(columns={
    df.columns[0]: "Domestic_Movement",
    df.columns[1]: "Month",
    df.columns[2]: "Airport"
}, inplace=True)

# %%
print(df)
# Out:
#    Domestic_Movement      Month      Airport   Unnamed: 3      Q2 2021  \
# 0                S/N   AIRPORTS  Q1 2021_ARR  Q1 2021_DEP  Q2 2021_ARR
# 1                  1      LAGOS       404939       359937       433881
# 2                  2      ABUJA       469599       462810       506374
# 3                  3        PHC        80225        84788        94135
# 4                  4       KANO        56021        56660        55127
# 5                  5      ENUGU        48283        55088        60615
# 6                  6      OSUBI            0            0            0
# 7                  7     KADUNA         9915         8838         5203
# 8                  8    CALABAR        17162        17647        20802
# 9                  9     SOKOTO        12442        12670        15449
# 10                10      BENIN        39241        40707        43843
# 11                11  MAIDUGURI        21892        22024        20600
# ...

# %% [markdown]
# ## Drop rows with mostly missing data

# %%
df.dropna(thresh=10, inplace=True)  # keep rows with at least 10 non-null values

# %%
df.columns = [f"col_{i}" for i in range(df.shape[1])]

# %%
print(df.columns.tolist())  # This should print: ['col_0', 'col_1', ..., 'col_87']
# Out:
# ['col_0', 'col_1', 'col_2', 'col_3', 'col_4', 'col_5', 'col_6', 'col_7', 'col_8', 'col_9', 'col_10', 'col_11', 'col_12', 'col_13', 'col_14', 'col_15', 'col_16', 'col_17', 'col_18', 'col_19', 'col_20', 'col_21', 'col_22', 'col_23', 'col_24', 'col_25', 'col_26', 'col_27', 'col_28', 'col_29', 'col_30', 'col_31', 'col_32', 'col_33', 'col_34', 'col_35', 'col_36', 'col_37', 'col_38', 'col_39', 'col_40', 'col_41', 'col_42', 'col_43', 'col_44', 'col_45', 'col_46', 'col_47', 'col_48', 'col_49', 'col_50', 'col_51', 'col_52', 'col_53', 'col_54', 'col_55', 'col_56', 'col_57', 'col_58', 'col_59', 'col_60', 'col_61', 'col_62', 'col_63', 'col_64', 'col_65', 'col_66', 'col_67', 'col_68', 'col_69', 'col_70', 'col_71', 'col_72', 'col_73', 'col_74', 'col_75', 'col_76', 'col_77', 'col_78', 'col_79', 'col_80', 'col_81', 'col_82', 'col_83', 'col_84', 'col_85', 'col_86', 'col_87', 'col_88']

# %%
df['col_20'] = pd.to_numeric(df['col_20'], errors='coerce')
